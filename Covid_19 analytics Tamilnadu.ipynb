# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import plotly.express as ex

df = pd.read_csv('../Desktop/districtwise_statistics_of_covid_19_cases_in_tn_as_on_28_04_2021.csv',index_col=0)
df.head()
# Out:
#           District  Total Positive Cases as on 28.04.2021  \
# S.No
# 1         Ariyalur                                   5485
# 2     Chengalpattu                                  77483
# 3          Chennai                                 323452
# 4       Coimbatore                                  76259
# 5        Cuddalore                                  29586
#
#       Discharged Cases as on 28.04.2021  Active Cases as on 28.04.2021  \
# S.No
# 1                                  5105                            328
# 2                                 68182                           8370
# 3                                287496                          31295
# 4                                 68619                           6921
# 5                                 27806                           1459
#
#       Death Cases as on 28.04.2021
# S.No
# 1                               52
# 2                              931
# 3                             4661
# ...

# %%
### Rename column for conveniance
df.rename(columns={'Total Positive Cases as on 28.04.2021':'Positive cases','Discharged Cases as on 28.04.2021':'Discharged cases','Active Cases as on 28.04.2021':'Active cases','Death Cases as on 28.04.2021':'Death cases'}, inplace=True)
df.tail()
# Out:
#                                    District  Positive cases  Discharged cases  \
# S.No
# 37                             Virudhunagar           19393             17870
# 38     Airport Surveillance (International)            1000               997
# 39          Airport Surveillance (Domestic)            1073              1067
# 40                     Railway Surveillance             428               428
# Total                           Grand Total         1130167           1006033
#
#        Active cases  Death cases
# S.No
# 37             1283          240
# 38                2            1
# 39                5            1
# 40                0            0
# Total        110308        13826

# %%
### Drop 'Total' row
dropped_Total_row = df.drop(['Total'],axis=0)
dropped_Total_row.tail()
# Out:
#                                   District  Positive cases  Discharged cases  \
# S.No
# 36                              Villupuram           18182             16586
# 37                            Virudhunagar           19393             17870
# 38    Airport Surveillance (International)            1000               997
# 39         Airport Surveillance (Domestic)            1073              1067
# 40                    Railway Surveillance             428               428
#
#       Active cases  Death cases
# S.No
# 36            1475          121
# 37            1283          240
# 38               2            1
# 39               5            1
# 40               0            0

# %%
### Plotting district wise positive cases
### Sort values
sorted_value = dropped_Total_row.sort_values(by=['Positive cases'],ascending=False)
### Generate a barplot
plt.figure(figsize=(12,25))
plot = sns.barplot(sorted_value['Positive cases'], sorted_value['District'])

for i, (value,name) in enumerate(zip(sorted_value['Positive cases'],sorted_value['District'])):
    plot.text(value,i-0.05,f'{value:,.0f}',size=10)
plt.show()
# Out:
# c:\users\sairashwanth sk\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
### Plotting district wise positive cases and recovered patients

plt.figure(figsize=(15,25))
positive = sns.barplot(sorted_value['Positive cases'], sorted_value['District'],color='red',label='Positive cases')
recovered = sns.barplot(sorted_value['Discharged cases'], sorted_value['District'],color='green',label='Recovered')

for i,(value,name) in enumerate(zip(sorted_value['Positive cases'],sorted_value['District'])):
    positive.text(value,i-0.05,f'{value:,.0f}',size=9)
    
for i,(value,name) in enumerate(zip(sorted_value['Discharged cases'],sorted_value['District'])):
    recovered.text(value,i-0.05,f'{value:,.0f}',size=9)
    
plt.legend(loc=4)
plt.show()
# Out:
# c:\users\sairashwanth sk\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\users\sairashwanth sk\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
